# %%
import pandas as pd
import numpy as np

path = "dataLaundry.csv"
df = pd.read_csv(path)
print(df)
# Out:
#                                                  link  \
# 0   https://www.google.com/maps/place/Fresh+Clean+...
# 1   https://www.google.com/maps/place/Hade+Laundry...
# 2   https://www.google.com/maps/place/Laundry+Satu...
# 3   https://www.google.com/maps/place/Amala+Expres...
# 4   https://www.google.com/maps/place/Sorcha+Laund...
# ..                                                ...
# 77  https://www.google.com/maps/place/Laundry+dimo...
# 78  https://www.google.com/maps/place/Up+Laundry+B...
# 79  https://www.google.com/maps/place/Xpress+laund...
# 80  https://www.google.com/maps/place/Tea+Laundry/...
# 81  https://www.google.com/maps/place/Wetklin/data...
#
#                                                 title          category  \
# 0                         Fresh Clean Laundry Bandung        Laundromat
# 1                           Hade Laundry Simpang Dago   Laundry service
# 2   Laundry Satuan-Laundry Kiloan-Laundry Express-...   Laundry service
# ...

# %%
df.head(3)
# Out:
#                                                 link  \
# 0  https://www.google.com/maps/place/Fresh+Clean+...
# 1  https://www.google.com/maps/place/Hade+Laundry...
# 2  https://www.google.com/maps/place/Laundry+Satu...
#
#                                                title         category  \
# 0                        Fresh Clean Laundry Bandung       Laundromat
# 1                          Hade Laundry Simpang Dago  Laundry service
# 2  Laundry Satuan-Laundry Kiloan-Laundry Express-...  Laundry service
#
#                                              address  \
# 0  Jl. Cijawura Hilir No.14, Cijaura, Kec. Buahba...
# 1  Jl. Ir. H. Juanda No.170, Lebak Siliwangi, Ban...
# 2  Jl. Pendawa No.25a, RW.68, Arjuna, Cicendo, Ba...
#
#                                           open_hours popular_times  \
# 0  {"Friday":["7 AM–8 PM"],"Monday":["7 AM–8 PM"]...            {}
# 1  {"Friday":["8 AM–5 PM"],"Monday":["8 AM–5 PM"]...            {}
# ...

# %%
df.head()
# Out:
#                                                 link  \
# 0  https://www.google.com/maps/place/Fresh+Clean+...
# 1  https://www.google.com/maps/place/Hade+Laundry...
# 2  https://www.google.com/maps/place/Laundry+Satu...
# 3  https://www.google.com/maps/place/Amala+Expres...
# 4  https://www.google.com/maps/place/Sorcha+Laund...
#
#                                                title         category  \
# 0                        Fresh Clean Laundry Bandung       Laundromat
# 1                          Hade Laundry Simpang Dago  Laundry service
# 2  Laundry Satuan-Laundry Kiloan-Laundry Express-...  Laundry service
# 3               Amala Express Laundry & Wet Cleaning       Laundromat
# 4  Sorcha Laundry Pajajaran (Laundry Antar Jemput...       Laundromat
#
#                                              address  \
# 0  Jl. Cijawura Hilir No.14, Cijaura, Kec. Buahba...
# 1  Jl. Ir. H. Juanda No.170, Lebak Siliwangi, Ban...
# 2  Jl. Pendawa No.25a, RW.68, Arjuna, Cicendo, Ba...
# ...

# %%
df.tail()
# Out:
#                                                  link               title  \
# 77  https://www.google.com/maps/place/Laundry+dimo...     Laundry dimonik
# 78  https://www.google.com/maps/place/Up+Laundry+B...  Up Laundry Bandung
# 79  https://www.google.com/maps/place/Xpress+laund...      Xpress laundry
# 80  https://www.google.com/maps/place/Tea+Laundry/...         Tea Laundry
# 81  https://www.google.com/maps/place/Wetklin/data...             Wetklin
#
#             category                                            address  \
# 77   Laundry service  Jl. Purwakarta 2 No.17, Central Antapani, Anta...
# 78   Laundry service  Kp. Cipanjak, Desa Blk. Komp. Setiabudi Regenc...
# 79   Laundry service  Jl. Muararajeun Baru No.6, Cihaur Geulis, Cibe...
# 80   Laundry service  Jl. Soma No.46, Babakan Surabaya, Kec. Kiaraco...
# 81  Corporate office  Jl. Belitung No.3, Merdeka, Bandung, Bandung C...
#
#                                            open_hours  \
# ...

# %%
print(df.dtypes)
# Out:
# link                   object
# title                  object
# category               object
# address                object
# open_hours             object
# popular_times          object
# website                object
# phone                  object
# plus_code              object
# review_count            int64
# review_rating         float64
# reviews_per_rating     object
# latitude              float64
# longitude             float64
# cid                    uint64
# status                 object
# descriptions          float64
# reviews_link           object
# thumbnail              object
# timezone               object
# price_range           float64
# data_id                object
# images                 object
# reservations          float64
# order_online           object
# menu                   object
# owner                  object
# complete_address       object
# about                  object
# user_reviews           object
# dtype: object

# %%
df_noid = df.iloc[:,2:]
df_noid
# Out:
#             category                                            address  \
# 0         Laundromat  Jl. Cijawura Hilir No.14, Cijaura, Kec. Buahba...
# 1    Laundry service  Jl. Ir. H. Juanda No.170, Lebak Siliwangi, Ban...
# 2    Laundry service  Jl. Pendawa No.25a, RW.68, Arjuna, Cicendo, Ba...
# 3         Laundromat  Jl. Merdeka No.25 - 27, Babakanciamis, Sumurba...
# 4         Laundromat  Jl. Rama No.26b, Arjuna, Cicendo, Bandung City...
# ..               ...                                                ...
# 77   Laundry service  Jl. Purwakarta 2 No.17, Central Antapani, Anta...
# 78   Laundry service  Kp. Cipanjak, Desa Blk. Komp. Setiabudi Regenc...
# 79   Laundry service  Jl. Muararajeun Baru No.6, Cihaur Geulis, Cibe...
# 80   Laundry service  Jl. Soma No.46, Babakan Surabaya, Kec. Kiaraco...
# 81  Corporate office  Jl. Belitung No.3, Merdeka, Bandung, Bandung C...
#
#                                            open_hours  \
# ...

# %%
df_noid.describe()
# Out:
#        review_count  review_rating   latitude   longitude           cid  \
# count     82.000000      82.000000  82.000000   82.000000  8.200000e+01
# mean      55.804878       4.454878  -6.909104  107.621038  9.206702e+18
# std      146.046622       0.886824   0.030199    0.030258  5.006179e+18
# min        0.000000       0.000000  -6.974752  107.558218  4.133726e+17
# 25%        5.250000       4.300000  -6.929254  107.602579  5.593768e+18
# 50%       18.000000       4.800000  -6.909609  107.617332  8.423459e+18
# 75%       37.000000       4.975000  -6.887847  107.634331  1.324119e+19
# max     1109.000000       5.000000  -6.844991  107.739824  1.843297e+19
#
#        descriptions  price_range  reservations
# count           0.0          0.0           0.0
# mean            NaN          NaN           NaN
# std             NaN          NaN           NaN
# min             NaN          NaN           NaN
# 25%             NaN          NaN           NaN
# ...

# %%
df_noid.describe(include='all')
# Out:
#                category                                            address  \
# count                82                                                 82
# unique                5                                                 80
# top     Laundry service  Jl. Cigadung Raya Timur No.65, Cigadung, Kec. ...
# freq                 50                                                  2
# mean                NaN                                                NaN
# std                 NaN                                                NaN
# min                 NaN                                                NaN
# 25%                 NaN                                                NaN
# 50%                 NaN                                                NaN
# 75%                 NaN                                                NaN
# max                 NaN                                                NaN
#
# ...

# %%
df_noid[['review_count', 'review_rating']].mean()
# Out:
# review_count     55.804878
# review_rating     4.454878
# dtype: float64

# %%
df_noid[['review_count', 'review_rating']].median()
# Out:
# review_count     18.0
# review_rating     4.8
# dtype: float64

# %%
df_noid[['review_rating', 'category']].mode()
# Out:
#    review_rating         category
# 0            5.0  Laundry service

# %%
df_noid[['review_count', 'review_rating']].quantile(q=0.75)
# Out:
# review_count     37.000
# review_rating     4.975
# Name: 0.75, dtype: float64

# %%
df_noid[['review_count']].var(), df_noid['review_count'].std()
# Out:
# (review_count    21329.615778
#  dtype: float64,
#  np.float64(146.04662193416183))

# %%
mean = df_noid[['review_count']].mean()
stdev = df_noid[['review_count']].std()
iso = (df_noid[['review_count']] < mean - 3*stdev) | (df_noid[['review_count']] > mean + 3*stdev)

df1 = df_noid[['category', 'review_rating']].assign(is_outlier=iso)
df1.loc[df1['is_outlier']]
# Out:
#            category  review_rating  is_outlier
# 12  Laundry service            4.9        True

# %%
df_noid['review_rating'].value_counts()
# Out:
# review_rating
# 5.0    21
# 4.9    16
# 4.3     6
# 4.7     6
# 4.0     5
# 4.8     5
# 4.6     4
# 4.4     4
# 4.2     2
# 4.1     2
# 4.5     2
# 1.0     2
# 3.8     1
# 3.4     1
# 2.7     1
# 3.9     1
# 0.0     1
# 3.5     1
# 3.0     1
# Name: count, dtype: int64

# %%
df_noid.groupby('category')[['review_rating']].mean().sort_values(by='review_rating', ascending=False)
# Out:
#                   review_rating
# category
# Corporate office       4.700000
# Laundromat             4.700000
# Dry cleaner            4.536364
# Laundry service        4.488000
# Laundry                4.150000

# %%
df_noid.corr(numeric_only=True)
# Out:
#                review_count  review_rating  latitude  longitude       cid  \
# review_count       1.000000       0.151738  0.033100  -0.121280  0.046294
# review_rating      0.151738       1.000000 -0.026708  -0.082515 -0.100944
# latitude           0.033100      -0.026708  1.000000  -0.348508 -0.033685
# longitude         -0.121280      -0.082515 -0.348508   1.000000  0.025012
# cid                0.046294      -0.100944 -0.033685   0.025012  1.000000
# descriptions            NaN            NaN       NaN        NaN       NaN
# price_range             NaN            NaN       NaN        NaN       NaN
# reservations            NaN            NaN       NaN        NaN       NaN
#
#                descriptions  price_range  reservations
# review_count            NaN          NaN           NaN
# review_rating           NaN          NaN           NaN
# latitude                NaN          NaN           NaN
# longitude               NaN          NaN           NaN
# ...

# %%
df_noid_values = df
df1 = df_noid_values.sort_values(by=['owner', 'review_count'], ascending=[True, False])
df1.head(10)
# Out:
#                                                  link  \
# 51  https://www.google.com/maps/place/AT+Laundry/d...
# 66  https://www.google.com/maps/place/Bee+Laundry/...
# 42  https://www.google.com/maps/place/Bersihin+Lau...
# 63  https://www.google.com/maps/place/Bio+Clean+La...
# 25  https://www.google.com/maps/place/Citra+Dry+Cl...
# 73  https://www.google.com/maps/place/DE+LAUNDRY+E...
# 39  https://www.google.com/maps/place/LAUNDRY+101/...
# 29  https://www.google.com/maps/place/LAUNDRY+FAMI...
# 58  https://www.google.com/maps/place/Laundrette/d...
# 52  https://www.google.com/maps/place/Laundry/data...
#
#                                  title         category  \
# 51                          AT Laundry          Laundry
# 66                         Bee Laundry  Laundry service
# 42                    Bersihin Laundry  Laundry service
# 63  Bio Clean Laundry Cabang Setiabudi  Laundry service
# 25           Citra Dry Clean & Laundry      Dry cleaner
# ...
